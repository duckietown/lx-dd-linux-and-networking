# %% [markdown]
# # SSH Access to a Physical Duckiedrone
#
# This notebook introduces SSH access to a physical Duckiedrone.
#
# ## Verify the intended Duckiedrone first
#
# From a base-station terminal on the approved network, verify only a Duckiedrone you own or are explicitly authorized to access.
#
# Before opening a remote shell, confirm that the known physical Duckiedrone is reachable on the intended network:
#
# ```bash
# getent hosts DUCKIEDRONE_NAME.local
# ping -c 3 DUCKIEDRONE_NAME.local
# ```
#
# Replace `DUCKIEDRONE_NAME` with the hostname assigned during provisioning. A failed lookup or ping is evidence to investigate through approved networking support; it is not permission to scan, change network settings, or try other devices. A successful ping also does not prove an SSH service is available.
#
# ## Open an authorized SSH session
#
# SSH is an encrypted text-terminal connection. Connect with the credential configured during provisioning rather than a shared default credential:
#
# ```bash
# ssh duckie@DUCKIEDRONE_NAME.local
# ```
#
# At the first connection, SSH displays a host-key fingerprint, a short identifier for the Duckiedrone's cryptographic identity. Confirm it only when it matches a fingerprint recorded during provisioning or supplied by the instructor. After the session opens, use `hostname` to verify where the terminal runs:
#
# ```bash
# hostname
# ```
#
# An unexpected host-key change for an existing hostname can mean the Duckiedrone was re-provisioned. Pause and verify that change before accepting it.
#
# ## Install one personal public key
#
# Only after an authorized password-authenticated login has worked and the host key is verified, you may choose to install one personal public key for future access. First check that the expected public key exists on the base station:
#
# ```bash
# ls ~/.ssh/id_ed25519.pub
# ```
#
# If it does not exist, use the institution's documented key-management process or ask the instructor. Do not generate a shared key merely to complete this learning experience. With explicit authorization to create persistent account access, install the public key:
#
# ```bash
# ssh-copy-id -i ~/.ssh/id_ed25519.pub duckie@DUCKIEDRONE_NAME.local
# ```
#
# `ssh-copy-id` opens a password-authenticated SSH connection and adds the selected public key to the Duckiedrone's authorized-key list. It asks for the provisioned password once. The matching private key remains on the base station: never copy it to the Duckiedrone or share it. This step will not work when password authentication is disabled or another key policy applies.
#
# For a later authorized connection, run `ssh duckie@DUCKIEDRONE_NAME.local`. No Duckiedrone password prompt indicates that the public key was accepted. A prompt for the private key passphrase is different: it protects the private key on the base station.
#
# ## Further reading
#
# OpenSSH's [`ssh` client manual](https://man.openbsd.org/ssh.1) and the [Duckietown Manual](https://docs.duckietown.com/ente/duckietown-manual/) provide setup and troubleshooting detail.
#
# ## Checkpoint
#
# Run the self-check in the next cell. Write or select a response before revealing the answer.

# %%
import sys
from pathlib import Path

working_directory = Path.cwd()
parent_directory = working_directory.parent
if (parent_directory / "packages").is_dir():
    parent_directory_path = str(parent_directory)
    sys.path.insert(0, parent_directory_path)

from packages.checkpoint_self_check import display_checkpoint_self_checks

display_checkpoint_self_checks()
